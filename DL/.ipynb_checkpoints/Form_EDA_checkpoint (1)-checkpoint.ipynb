# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# %%
df = pd.read_excel("Form.xlsx")
df
# Out:
#                   طابع زمني                         الاسم موقعك الحالي  \
# 0   2024-08-19 00:26:18.931                           NaN      الشرقية
# 1   2024-08-19 00:27:29.272              اسامه حسن منصور       الشرقية
# 2   2024-08-19 00:33:12.809               عمر ايمن السيد       الشرقية
# 3   2024-08-19 00:35:05.869    محمد السيد عبدالعال الديب       الشرقية
# 4   2024-08-19 00:36:10.167  Khaled nasr abdellatif nasr      المنصورة
# ..                      ...                           ...          ...
# 333 2024-08-24 01:08:07.936                           NaN      القاهرة
# 334 2024-08-24 15:52:40.209                           NaN     المنصورة
# 335 2024-08-24 18:51:09.464                         Somya       بَنْها
# 336 2024-08-25 13:03:49.845                     يمنى احمد      الشرقية
# 337 2024-08-28 15:43:20.947                         Noura      القاهرة
#
#     ساكن فين؟ ما هو عمرك؟ زرعت او اهتميت بشجره قبل كدا؟  \
# 0        قرية       18-30                            لا
# ...

# %%
# Check the first few rows
print(df.head())
# Out:
#                 طابع زمني                         الاسم موقعك الحالي  \
# 0 2024-08-19 00:26:18.931                           NaN      الشرقية
# 1 2024-08-19 00:27:29.272              اسامه حسن منصور       الشرقية
# 2 2024-08-19 00:33:12.809               عمر ايمن السيد       الشرقية
# 3 2024-08-19 00:35:05.869    محمد السيد عبدالعال الديب       الشرقية
# 4 2024-08-19 00:36:10.167  Khaled nasr abdellatif nasr      المنصورة
#
#   ساكن فين؟ ما هو عمرك؟ زرعت او اهتميت بشجره قبل كدا؟ في شجر كتير في مدينتك؟  \
# 0      قرية       18-30                            لا                   ربما
# 1     مدينة       18-30                            لا                     لا
# 2     مدينة       18-30                            لا                     لا
# 3      قرية       18-30                           نعم                    نعم
# 4      قرية       18-30                            لا                     لا
#
#   شاركت قبل كدا في زراعة الاشجار ف مدينتك؟  \
# ...

# %%
# Dataframe summary
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 338 entries, 0 to 337
# Data columns (total 13 columns):
#  #   Column                                                                        Non-Null Count  Dtype
# ---  ------                                                                        --------------  -----
#  0   طابع زمني                                                                     338 non-null    datetime64[ns]
#  1   الاسم                                                                         304 non-null    object
#  2   موقعك الحالي                                                                  338 non-null    object
#  3   ساكن فين؟                                                                     338 non-null    object
#  4   ما هو عمرك؟                                                                   338 non-null    object
#  5   زرعت او اهتميت بشجره قبل كدا؟                                                 338 non-null    object
# ...

# %%
# Statistical summary
print(df.describe())
# Out:
#                            طابع زمني
# count                            338
# mean   2024-08-20 11:38:17.260319744
# min       2024-08-19 00:26:18.931000
# 25%    2024-08-19 05:55:47.076499968
# 50%    2024-08-20 19:30:28.659500032
# 75%    2024-08-21 07:00:51.876499968
# max       2024-08-28 15:43:20.947000

# %%
# View the column names
print(df.columns)
# Out:
# Index(['طابع زمني', 'الاسم', 'موقعك الحالي', 'ساكن فين؟', 'ما هو عمرك؟',
#        'زرعت او اهتميت بشجره قبل كدا؟', 'في شجر كتير في مدينتك؟',
#        'شاركت قبل كدا في زراعة الاشجار ف مدينتك؟',
#        'اي هي الصعوبات التي تواجهها في المشاركة أو دعم جهود زراعة الاشجار في مدينتك؟',
#        'عندك معلومات عن ازاي تزرع الشجر؟',
#        'في صعوبة في انك تلاقي معلومات عن زراعة الأشجار؟',
#        '  عندك حديقة أو مساحة خارجية في بيتك تقدر تزرع شجر فيها؟  ',
#        'لو فكرت قبل كده ففكره تساعد في انتشار المساحات الخضراء ممكن تشاركها معانا؟'],
#       dtype='object')

# %%
# Check data types of columns
print(df.dtypes)
# Out:
# طابع زمني                                                                       datetime64[ns]
# الاسم                                                                                   object
# موقعك الحالي                                                                            object
# ساكن فين؟                                                                               object
# ما هو عمرك؟                                                                             object
# زرعت او اهتميت بشجره قبل كدا؟                                                           object
# في شجر كتير في مدينتك؟                                                                  object
# شاركت قبل كدا في زراعة الاشجار ف مدينتك؟                                                object
# اي هي الصعوبات التي تواجهها في المشاركة أو دعم جهود زراعة الاشجار في مدينتك؟            object
# عندك معلومات عن ازاي تزرع الشجر؟                                                        object
# ...

# %%
df.shape
# Out:
# (338, 13)

# %% [markdown]
# # Cleaning Data

# %%
#Check for missing values
print("Missing values before cleaning:\n", df.isnull().sum())
# Out:
# Missing values before cleaning:
#  طابع زمني                                                                         0
# الاسم                                                                            34
# موقعك الحالي                                                                      0
# ساكن فين؟                                                                         0
# ما هو عمرك؟                                                                       0
# زرعت او اهتميت بشجره قبل كدا؟                                                     0
# في شجر كتير في مدينتك؟                                                            0
# شاركت قبل كدا في زراعة الاشجار ف مدينتك؟                                          0
# اي هي الصعوبات التي تواجهها في المشاركة أو دعم جهود زراعة الاشجار في مدينتك؟      0
# عندك معلومات عن ازاي تزرع الشجر؟                                                  0
# في صعوبة في انك تلاقي معلومات عن زراعة الأشجار؟                                   0
# ...

# %%
#Drop rows where 'الاسم' (Name) is missing
df_cleaned = df.dropna(subset=['الاسم'])

# %%
#Drop rows where'لو فكرت قبل كده ففكره تساعد في انتشار المساحات الخضراء ممكن تشاركها معانا؟' is missing
df_cleaned = df.dropna(subset=['لو فكرت قبل كده ففكره تساعد في انتشار المساحات الخضراء ممكن تشاركها معانا؟'])

# %%
#Remove duplicate rows
df_cleaned = df_cleaned.drop_duplicates()

# %%
#Re-check for missing values after cleaning
print("Missing values after cleaning:\n", df_cleaned.isnull().sum())
# Out:
# Missing values after cleaning:
#  طابع زمني                                                                       0
# الاسم                                                                           9
# موقعك الحالي                                                                    0
# ساكن فين؟                                                                       0
# ما هو عمرك؟                                                                     0
# زرعت او اهتميت بشجره قبل كدا؟                                                   0
# في شجر كتير في مدينتك؟                                                          0
# شاركت قبل كدا في زراعة الاشجار ف مدينتك؟                                        0
# اي هي الصعوبات التي تواجهها في المشاركة أو دعم جهود زراعة الاشجار في مدينتك؟    0
# عندك معلومات عن ازاي تزرع الشجر؟                                                0
# في صعوبة في انك تلاقي معلومات عن زراعة الأشجار؟                                 0
# ...

# %%
# Display the first few rows of cleaned data
print(df_cleaned.head())
# Out:
#                 طابع زمني                         الاسم موقعك الحالي  \
# 2 2024-08-19 00:33:12.809               عمر ايمن السيد       الشرقية
# 4 2024-08-19 00:36:10.167  Khaled nasr abdellatif nasr      المنصورة
# 5 2024-08-19 00:36:48.054                    عمرو دياب       الشرقية
# 6 2024-08-19 00:40:47.389       أحمد رشاد المحمودي غريب      الشرقية
# 8 2024-08-19 00:49:34.702        حسن حسين محسن الحسيني       الشرقية
#
#   ساكن فين؟ ما هو عمرك؟ زرعت او اهتميت بشجره قبل كدا؟ في شجر كتير في مدينتك؟  \
# 2     مدينة       18-30                            لا                     لا
# 4      قرية       18-30                            لا                     لا
# 5     مدينة       18-30                            لا                     لا
# 6      قرية       18-30                           نعم                    نعم
# 8      قرية       18-30                            لا                   ربما
#
#   شاركت قبل كدا في زراعة الاشجار ف مدينتك؟  \
# ...

# %%
# Drop the columns
df = df.drop(columns=['الاسم', 'طابع زمني'])
df
